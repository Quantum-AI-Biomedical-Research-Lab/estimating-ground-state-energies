# %% [markdown]
# # Commutativity checker for fermionic excitations in second quantization
#
# The excitations are not dependent on the molecule in question. They can be generated by specifying
#
# 1. the number of spatial orbitals: `num_spatial`
# 2. the number of alpha and beta spins: `num_particles = (num_alpha, num_beta)`
#
# For example, for the $H_2$ molecule, there are 2 spatial orbitals, one $\alpha$-spin particle (spin-up), and one $\beta$-spin particle (spin-down). Therefore, the parameters look like follows:
#
# `num_spatial = 2`
#
# `num_particles = (1, 1)`
#
# Note that this is a full commutation, or algebraic commutativity, checker. Two Pauli strings commute fully iff the number of positions where they differ by non-identity Pauli operators is even. This type of commutation plays a role in defining a VQE ansatz using excitation terms.
#
# For use with Hamiltonian terms in VQE, use qubit-wise commutativity (see the second cell of this notebook).

# %%
from qiskit_nature.second_q.operators import FermionicOp
from qiskit_nature.second_q.circuit.library.ansatzes.utils import generate_fermionic_excitations
from qiskit_nature.second_q.mappers import JordanWignerMapper
import numpy as np
from IPython.display import display, Math

# --- Helper function for clean printing ---
def print_clean_pauli(op):
    """Prints coefficients and Pauli strings line by line."""
    for pauli, coeff in zip(op.paulis, op.coeffs):
        if np.isclose(coeff.imag, 0.0):
            c_str = f"{coeff.real:.4f}"
        elif np.isclose(coeff.real, 0.0):
            c_str = f"{coeff.imag:.4f}j"
        else:
            c_str = f"{coeff:.4f}"
        print(f"  {c_str:>10} * {pauli}")

# 1. SETUP PARAMETERS (MODIFY TO YOUR NEEDS)
num_spatial = 2
num_particles = (1, 1)
num_spin_orbitals = num_spatial * 2    # don't modify

mapper = JordanWignerMapper()

# 2. Get excitations
raw_excitations = []
for rank in [1, 2]:
    raw_excitations += generate_fermionic_excitations(
        num_excitations=rank, 
        num_spatial_orbitals=num_spatial, 
        num_particles=num_particles,
        alpha_spin=True,
        beta_spin=True
    )

print(f"Generated {len(raw_excitations)} raw excitations.\n")

# 3. Build generators
pauli_generators = []
labels = []

display(Math(r"\text{--- 1. Generators and Pauli decomposition ---}"))

for i, exc in enumerate(raw_excitations):
    occ_indices = exc[0]
    vir_indices = exc[1]

    # --- Build The forward term (T) ---
    # Creation on virtual orbitals, annihilation on occupied orbitals
    forward_creation = " ".join([f"a^\\dagger_{{{idx}}}" for idx in vir_indices])
    forward_annihilation = " ".join([f"a_{{{idx}}}" for idx in occ_indices])
    
    # --- Build The conjugate term (T_dagger) ---
    # To find the Hermitian conjugate:
    # 1. Swap creation <-> annihilation
    # 2. Swap indices (occupied <-> virtual)
    # 3. Reverse the order ( (AB)^dagger = B^dagger A^dagger )
    
    # Conjugate of the annihilation part becomes creation (reversed)
    # e.g. (a_0 a_1)^dagger -> a^dagger_1 a^dagger_0
    hc_creation = " ".join([f"a^\\dagger_{{{idx}}}" for idx in reversed(occ_indices)])
    
    # Conjugate of the creation part becomes annihilation (reversed)
    # e.g. (a^dagger_2 a^dagger_3)^dagger -> a_3 a_2
    hc_annihilation = " ".join([f"a_{{{idx}}}" for idx in reversed(vir_indices)])

    # Construct full label
    latex_label = f"G_{{{i}}} = {forward_creation} {forward_annihilation} - {hc_creation} {hc_annihilation}"
    labels.append(latex_label)

    # --- Build operator object ---
    creation_part = " ".join([f"+_{idx}" for idx in vir_indices])
    annihilation_part = " ".join([f"-_{idx}" for idx in occ_indices])
    op_str = f"{creation_part} {annihilation_part}"
    
    T_op = FermionicOp({op_str: 1.0}, num_spin_orbitals=num_spin_orbitals)
    G_op = T_op - T_op.adjoint()
    
    qubit_op = mapper.map(G_op).simplify()
    pauli_generators.append(qubit_op)
    
    # Render
    display(Math(latex_label))
    print_clean_pauli(qubit_op)
    print("-" * 30)

# 4. Check commutation
display(Math(r"\text{--- 2. Non-commuting pairs ---}"))
non_commuting_pairs = 0

for i in range(len(pauli_generators)):
    for j in range(i + 1, len(pauli_generators)):
        op_i = pauli_generators[i]
        op_j = pauli_generators[j]
        
        commutator = (op_i @ op_j) - (op_j @ op_i)
        commutator = commutator.simplify()
        
        if not np.all(np.isclose(commutator.coeffs, 0.0)):
            # Render the pair label
            comm_latex = f"[{labels[i]}, \\quad {labels[j]}] \\neq 0"
            display(Math(comm_latex))
            
            print("Residual Pauli terms:")
            print_clean_pauli(commutator)
            print("-" * 30)
            
            non_commuting_pairs += 1

print(f"\nSummary: Found {non_commuting_pairs} non-commuting pairs out of {len(raw_excitations)*(len(raw_excitations)-1)//2} total pairs.")
# Out:
# Generated 3 raw excitations.
# $\displaystyle \text{--- 1. Generators and Pauli decomposition ---}$
# $\displaystyle G_{0} = a^\dagger_{1} a_{0} - a^\dagger_{0} a_{1}$
#      0.5000j * IIXY
#     -0.5000j * IIYX
# ------------------------------
# $\displaystyle G_{1} = a^\dagger_{3} a_{2} - a^\dagger_{2} a_{3}$
#      0.5000j * XYII
#     -0.5000j * YXII
# ------------------------------
# $\displaystyle G_{2} = a^\dagger_{1} a^\dagger_{3} a_{0} a_{2} - a^\dagger_{2} a^\dagger_{0} a_{3} a_{1}$
#     -0.1250j * XXXY
#     -0.1250j * XYXX
#     -0.1250j * YYXY
#      0.1250j * YXXX
#     -0.1250j * XYYY
#      0.1250j * XXYX
#      0.1250j * YXYY
#      0.1250j * YYYX
# ------------------------------
# $\displaystyle \text{--- 2. Non-commuting pairs ---}$
# $\displaystyle [G_{0} = a^\dagger_{1} a_{0} - a^\dagger_{0} a_{1}, \quad G_{2} = a^\dagger_{1} a^\dagger_{3} a_{0} a_{2} - a^\dagger_{2} a^\dagger_{0} a_{3} a_{1}] \neq 0$
# Residual Pauli terms:
#     -0.2500j * XYIZ
#      0.2500j * YXIZ
#      0.2500j * XYZI
#     -0.2500j * YXZI
# ------------------------------
# $\displaystyle [G_{1} = a^\dagger_{3} a_{2} - a^\dagger_{2} a_{3}, \quad G_{2} = a^\dagger_{1} a^\dagger_{3} a_{0} a_{2} - a^\dagger_{2} a^\dagger_{0} a_{3} a_{1}] \neq 0$
# Residual Pauli terms:
#     -0.2500j * IZXY
#      0.2500j * ZIXY
#      0.2500j * IZYX
#     -0.2500j * ZIYX
# ------------------------------
#
# Summary: Found 2 non-commuting pairs out of 3 total pairs.

# %% [markdown]
# ---
#
# # Qubit-wise commutativity checker for Hamiltonian terms
#
# Qubit-wise commutativity is stricter than the full commutativity. Two Pauli strings commute qubit-wise iff on every qubit:
#
# * the operators are identical, or
# * at least one is identity
#
# In VQE, Hamiltonian terms that commute qubit-wise can be measured in the same measurement basis.

# %%
from qiskit.quantum_info import SparsePauliOp, Pauli
import networkx as nx

def qubit_wise_commutes(p1: Pauli, p2: Pauli) -> bool:
    """Check qubit-wise commutation between two Pauli operators."""
    label1 = p1.to_label()
    label2 = p2.to_label()
    for a, b in zip(label1, label2):
        if a != "I" and b != "I" and a != b:
            return False
    return True

def minimal_qubitwise_commuting_groups(pauli_op: SparsePauliOp):
    """
    Group SparsePauliOp terms into minimal qubit-wise commuting sets using graph coloring.
    
    Returns:
        grouped_ops: list of SparsePauliOp objects, each a qubit-wise commuting group
    """
    terms = list(zip(pauli_op.paulis, pauli_op.coeffs))
    n_terms = len(terms)
    
    # Step 1: Build anti-commutation graph (edges between non-qubit-wise-commuting terms)
    G = nx.Graph()
    G.add_nodes_from(range(n_terms))
    
    for i in range(n_terms):
        for j in range(i + 1, n_terms):
            if not qubit_wise_commutes(terms[i][0], terms[j][0]):
                G.add_edge(i, j)
    
    # Step 2: Deterministic coloring: largest_first with sorted nodes
    coloring = nx.coloring.greedy_color(G, strategy='largest_first')
    
    # Step 3: Build groups based on coloring
    groups_dict = {}
    for idx, color in coloring.items():
        if color not in groups_dict:
            groups_dict[color] = []
        groups_dict[color].append(terms[idx])
    
    # Step 4: Convert groups to SparsePauliOp
    grouped_ops = []
    for group in groups_dict.values():
        paulis, coeffs = zip(*group)
        grouped_ops.append(SparsePauliOp(list(paulis), coeffs=list(coeffs)))
    
    return grouped_ops

# ---------------- Example ----------------
H = SparsePauliOp.from_list([
    ("ZX", 0.5),
    ("XZ", 0.3),
    ("ZZ", 1.0),
    ("XI", 0.7),
    ("IZ", 0.6),
    ("YY", 0.4)
])

groups = minimal_qubitwise_commuting_groups(H)

print(f"Minimal number of qubit-wise commuting groups: {len(groups)}\n")
for i, g in enumerate(groups):
    print(f"Group {i+1}:")
    for p, c in zip(g.paulis, g.coeffs):
        print(f"  {p.to_label()} : {c}")

print('\nList of SparsePauliOps ready for VQE:', groups)
# Out:
# Minimal number of qubit-wise commuting groups: 4
#
# Group 1:
#   ZX : (0.5+0j)
# Group 2:
#   YY : (0.4+0j)
# Group 3:
#   ZZ : (1+0j)
#   IZ : (0.6+0j)
# Group 4:
#   XZ : (0.3+0j)
#   XI : (0.7+0j)
#
# List of SparsePauliOps ready for VQE: [SparsePauliOp(['ZX'],
#               coeffs=[0.5+0.j]), SparsePauliOp(['YY'],
#               coeffs=[0.4+0.j]), SparsePauliOp(['ZZ', 'IZ'],
#               coeffs=[1. +0.j, 0.6+0.j]), SparsePauliOp(['XZ', 'XI'],
#               coeffs=[0.3+0.j, 0.7+0.j])]

# %% [markdown]
# ---
#
# # Comparison of full commutativity with qubit-wise commutativity
#
# Please specify the terms to compare in the variable `H`. Note that the grouping is in general not unique.

# %%
from qiskit.quantum_info import SparsePauliOp, Pauli


def commutes_qubit_wise(p1, p2):
    label1 = p1.to_label()
    label2 = p2.to_label()

    for a, b in zip(label1, label2):
        if a != b and a != "I" and b != "I":
            return False
    return True


def group_commuting_terms(pauli_op: SparsePauliOp, qubit_wise=True):
    """
    Group Hamiltonian terms into mutually commuting sets.

    Parameters
    ----------
    pauli_op : SparsePauliOp
        Hamiltonian
    qubit_wise : bool
        If True, group by qubit-wise commutation (VQE measurement)
        If False, group by full commutation

    Returns
    -------
    list[list[int]]
        Groups of indices corresponding to pauli_op terms
    """
    paulis = pauli_op.paulis
    groups = []

    for i, p in enumerate(paulis):
        placed = False

        for group in groups:
            if all(
                commutes_qubit_wise(p, paulis[j]) if qubit_wise
                else p.commutes(paulis[j])
                for j in group
            ):
                group.append(i)
                placed = True
                break

        if not placed:
            groups.append([i])

    return groups

def print_groups(pauli_op, groups):
    for k, group in enumerate(groups):
        print(f"Group {k}:")
        for i in group:
            print(f"  {pauli_op.paulis[i].to_label()}  (coeff={pauli_op.coeffs[i]})")




# Example

H = SparsePauliOp.from_list([
    ("YY", 0.5),
    ("ZZ", 0.3),
    ("XX", 0.3),
])

groups_qwc = group_commuting_terms(H, qubit_wise=True)
groups_full = group_commuting_terms(H, qubit_wise=False)

print("Qubit-wise commuting groups:")
print_groups(H, groups_qwc)

print("\nFull-commuting groups:")
print_groups(H, groups_full)
# Out:
# Qubit-wise commuting groups:
# Group 0:
#   YY  (coeff=(0.5+0j))
# Group 1:
#   ZZ  (coeff=(0.3+0j))
# Group 2:
#   XX  (coeff=(0.3+0j))
#
# Full-commuting groups:
# Group 0:
#   YY  (coeff=(0.5+0j))
#   ZZ  (coeff=(0.3+0j))
#   XX  (coeff=(0.3+0j))

# %%
# %pip list | grep qiskit
# Out:
# qiskit                  2.2.3
# qiskit-aer              0.17.2
# qiskit-algorithms       0.4.0
# qiskit-ibm-runtime      0.44.0
# qiskit-nature           0.7.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <div style="background-color:#f0f0f0; padding:10px; border-radius:5px;">
# This code is a part of Quantum AI Biomedical Research Lab project
#
# `Estimating molecular ground and excited state energies on quantum computers'
#
# © Copyright Renata Wong, 2026.
#
# This code is licensed under the CC BY-NC 4.0 License. You may
# obtain a copy of this license in the LICENSE.txt file in the root directory
# of this source tree or at https://creativecommons.org/licenses/by-nc/4.0/deed.en.
#
# Any modifications or derivative works of this code must retain this
# copyright notice, and modified files need to carry a notice indicating
# that they have been altered from the originals.
# </div>

# %% [markdown]
# <div style="background-color:#f0f0f0; padding:10px; border-radius:5px;">
# This work was supported by the National Science and Technology Council (Taiwan) grant No. NSTC 114-2112-M-182-002-MY3 and Chang Gung Memorial Hospital grant No. BMRPL94.
#
# This work comes with an accompanying paper titled 'Quantum circuit compilation for fermionic excitations using the Jordan-Wigner mapping'.
# </div>
